# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Laila\\Downloads\\Task2'

# %%
import pandas as pd

# %%
data = pd.read_excel("distribution_of_schools_classes_students_teachers_by_education_level_and_department_for_2017_-2.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  توزيــــــع المـــدارس حســــب إدارات التعليــ...
# 1         NaN                                                NaN
# 2         NaN                                   المنطقة الإدارية
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
#       Unnamed: 2 Unnamed: 3   Unnamed: 4            Unnamed: 5 Unnamed: 6  \
# 0            NaN        NaN          NaN                   NaN        NaN
# 1            NaN        NaN          NaN                   NaN        NaN
# 2  إدارة التعليم      الجنس  نوع التعليم  ريــــاض أطفــــــال        NaN
# 3            NaN        NaN          NaN                 حكومي       أهلي
# 4            NaN        NaN          NaN                   NaN        NaN
#
#   Unnamed: 7          Unnamed: 8 Unnamed: 9  ... Unnamed: 20 Unnamed: 21  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 615         NaN        NaN        NaN        NaN       تحفيظ
# 616         NaN        NaN        NaN        NaN  تربية خاصة
# 617         NaN        NaN        NaN        NaN        جملة
# 618         NaN      مجموع        NaN        NaN         NaN
# 619         NaN   الاجمالي        NaN        NaN         NaN
#
#             Unnamed: 5 Unnamed: 6 Unnamed: 7      Unnamed: 8 Unnamed: 9  ...  \
# 615                  0          0          0             527         69  ...
# 616                  0          0          0               2          0  ...
# 617               2132       1272       3404            6322        780  ...
# 618               2132       1272       3404           12647       1390  ...
# 619  اجمالي رياض أطفال        NaN       3404  اجمالي ابتدائي        NaN  ...
#
#     Unnamed: 20        Unnamed: 21 Unnamed: 22 Unnamed: 23        Unnamed: 24  \
# ...

# %%
headers = ["school","address","management","sex","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","guardian","traveltime","studytime","failures","schoolsup","famsup","paid","activities","nursery","higher","internet","romantic","famrel","freetime","goout","Dalc","Walc","health","absences"]
print("headers\n", headers)
# Out:
# headers
#  ['school', 'address', 'management', 'sex', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']

# %%
data.columns = headers
data.head(15)
# Out:
#     school                                            address     management  \
# 0      NaN  توزيــــــع المـــدارس حســــب إدارات التعليــ...            NaN
# 1      NaN                                                NaN            NaN
# 2      NaN                                   المنطقة الإدارية  إدارة التعليم
# 3      NaN                                                NaN            NaN
# 4      NaN                                                NaN            NaN
# 5      NaN                                          الريـــاض         الرياض
# 6      NaN                                                NaN            NaN
# 7      NaN                                                NaN            NaN
# 8      NaN                                                NaN            NaN
# 9      NaN                                                NaN            NaN
# 10     NaN                                                NaN            NaN
# ...

# %%
data1=data.replace('?',np.NaN)

# %%
data=data.dropna(subset=["sex"], axis=0)
data.head(20)
# Out:
#     school           address             management    sex      famsize  \
# 2      NaN  المنطقة الإدارية          إدارة التعليم  الجنس  نوع التعليم
# 5      NaN         الريـــاض                 الرياض   ذكور        نهاري
# 10     NaN               NaN                    NaN   إناث        نهاري
# 15     NaN               NaN                الأفلاج   ذكور        نهاري
# 20     NaN               NaN                    NaN   إناث        نهاري
# 25     NaN               NaN  حوطة بني تميم والحريق   ذكور        نهاري
# 30     NaN               NaN                    NaN   إناث        نهاري
# 35     NaN               NaN                  الخرج   ذكور        نهاري
# 40     NaN               NaN                    NaN   إناث        نهاري
# 45     NaN               NaN               الدوادمي   ذكور        نهاري
# 50     NaN               NaN                    NaN   إناث        نهاري
# 55     NaN               NaN                 الزلفي   ذكور        نهاري
# ...
